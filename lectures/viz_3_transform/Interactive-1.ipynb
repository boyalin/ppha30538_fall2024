# %% [markdown]
# Connected to Python 3.9.6

# %%
import pandas as pd
import altair as alt

# %%
movies_url = 'https://cdn.jsdelivr.net/npm/vega-datasets@1/data/movies.json'

# %%
movies = pd.read_json(movies_url)

# %%
movies = pd.read_json('data/movies.json')

# %%
alt.Chart(movies_url).mark_circle().encode(
    alt.X('Rotten_Tomatoes_Rating:Q'),
    alt.Y('IMDB_Rating:Q')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(movies_url).mark_circle().encode(
    alt.X('Rotten_Tomatoes_Rating:Q', bin=alt.BinParams(maxbins=20)),
    alt.Y('IMDB_Rating:Q')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(movies_url).mark_bar().encode(
    alt.X('average(Rotten_Tomatoes_Rating):Q'),
    alt.Y('Major_Genre:N')
)
# Out:
# alt.Chart(...)

# %%
#Attribution: ChatGPT
#Query: I have the following bar chart code in Altair [...] 
# I want to sort the bars by the X encoding (average rotten tomatoes rating). How can I do that?
alt.Chart(movies_url).mark_bar().encode(
    alt.X('average(Rotten_Tomatoes_Rating):Q'),
    alt.Y('Major_Genre:N', 
        sort=alt.EncodingSortField(
            op='average', 
            field='Rotten_Tomatoes_Rating', 
            order='descending'
        )
    )
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(movies_url).mark_bar().encode(
    alt.X('q1(Rotten_Tomatoes_Rating):Q'),
    alt.X2('q3(Rotten_Tomatoes_Rating):Q'),
    alt.Y('Major_Genre:N', sort=alt.EncodingSortField(
        op='median', field='Rotten_Tomatoes_Rating', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()
# Out:
#     US Gross Release Date
# 0   146083.0  Jun 12 1998
# 1    10876.0  Aug 07 1998
# 2   203134.0  Aug 28 1998
# 3   373615.0  Sep 11 1998
# 4  1009819.0  Oct 09 1998

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()


alt.Chart(movies_gross).mark_bar().encode(
    alt.X('Release Date:T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', field='sum(US Gross):Q', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()


alt.Chart(movies_gross).mark_bar().encode(
    alt.X('Release Date:T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()


alt.Chart(movies_gross).mark_line().encode(
    alt.X('Release Date:T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('Release Date:T'),
    alt.Y('max(sum(US Gross)):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('Release Date:T'),
    alt.Y('max(sum(US Gross)):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('Release Date:T'),
    alt.Y('max(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('Release Date:T'),
    alt.Y('max(US Gross):Q')
    )
)
# Out:
#   Cell In[17], line 8
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('Release Date:T'),
    alt.Y('max(US Gross):Q')
    )
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release_Date):T'),
    alt.Y('(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('max(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# Out:
# alt.Chart(...)

# %%
movies_gross = movies[['US Gross', 'Release Date']]
movies_gross.head()

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('sum(US Gross):Q', sort=alt.EncodingSortField(
        op='median', order='descending')
    )
)
# sum: two peaks for both summer and winter holiday

alt.Chart(movies_gross).mark_line().encode(
    alt.X('month(Release Date):T'),
    alt.Y('median(US Gross):Q')
    )
# Out:
# alt.Chart(...)
